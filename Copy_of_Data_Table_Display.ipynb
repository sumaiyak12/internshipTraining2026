# %% [markdown]
# <a href="https://colab.research.google.com/github/sumaiyak12/internshipTraining2026/blob/main/Copy_of_Data_Table_Display.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
name = ("Sumaiya Khan")
age = 20
age = 25
college = "SRMCEM"
print(name)
print(age)
print(college)
# Out:
# Sumaiya Khan
# 25
# SRMCEM

# %%
a,b = 23,45
a,b = b,a
print(a)
# Out:
# 45

# %%
a=1.234
print(int(a))
#data type conversion
# Out:
# 1

# %%
name = input("Enter your name here: ")
collegeName = input("Enter your college name here: ")
departmentName = input("Enter your department name here: ")
age = int(input("Enter your age :"))
print(name)
print(collegeName)
print(departmentName)
print(age)
# Out:
# Enter your name here: SUMI
# Enter your college name here: SRMCEM
# Enter your department name here: BTECH
# Enter your age :78
# 15
# SRMCEM
# BTECH
# 78

# %%
a=10
b=20
print(a+b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)

# %%
age = int(input("Enter your age here:"))
if age >= 18 and age<=200:
  print("Elegible")
else:
  print("Not Eligible")
# Out:
# Enter your age here:199
# Elegible

# %%
marks = int(input("Enter your marks here:"))
if marks > 90:
  print("A")
elif marks <=90 and marks >= 80:
  print("B")
elif marks < 80 and marks >=70:
  print("C")
else:
  print("D")
# Out:
# Enter your marks here:56
# D

# %%
num = int(input("Enter your num here:"))
if  num % 3 == 0 and num % 5 == 0:
  print("Divisible by both 3 & 5")
elif num % 5 == 0:
  print("Divisible by 5")
elif num % 3 == 0:
  print("Divisible by 3")
else:
  print("not divisible")
# Out:
# Enter your num here:56
# not divisible

# %%
name = input("Enter your name here: ")
age = int(input("Enter your age :"))
marks = int(input("Enter your marks :"))
phoneNum = int(input("Enter your phoneNum :"))
collegeName = input("Enter your college name here: ")
if age >= 20 and marks >=60:
  print("Eligible")
  print(name)
  print(age)
  print(marks)
  print(phoneNum)
  print(collegeName)
  print(departmentName)
else:
  print("Not Eligible")
# Out:
# Enter your name here: Sumaiya
# Enter your age :25
# Enter your marks :70
# Enter your phoneNum :8706251836
# Enter your college name here: SRMCEM
# Eligible
# Sumaiya
# 25
# 70
# 8706251836
# SRMCEM
# BTECH

# %%
# Input purchase amount
purchase = float(input("Enter purchase amount (₹): "))

# Categorize buyer based on spending
if purchase < 10000:
    category = "Bronze Buyer"
elif purchase < 30000:
    category = "Silver Buyer"
elif purchase < 40000:
    category = "Gold Buyer"
else:
    category = "Platinum Buyer"

print(f"Purchase Amount: ₹{purchase:.2f}")
print(f"Buyer Category: {category}")
# Out:
# Enter purchase amount (₹): 56000
# Purchase Amount: ₹56000.00
# Buyer Category: Platinum Buyer

# %%
num1 = float(input("Enter first number: "))
op = input("Enter operator (+, -, *, /): ")
num2 = float(input("Enter second number: "))

if op == "+":
    print("Result:", num1 + num2)

elif op == "-":
    print("Result:", num1 - num2)

elif op == "*":
    print("Result:", num1 * num2)

elif op == "/":
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Cannot divide by zero")

else:
    print("Invalid operator")
# Out:
# Enter first number: 10
# Enter operator (+, -, *, /): +
# Enter second number: 20
# Result: 30.0

# %%
for i in range (0,5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
num = int(input("Enter any number:"))
count=0
while num > 0:
  d = num%10
  count+=1
  num //= 10

if count == 1:
  print("Single Digit")
elif count == 2:
  print("double digit")
else:
  print(f"{count} Digit Number")
# Out:
# Enter any number:4567
# 4 Digit Number

# %%
import pandas as pd
df = pd.read_csv("")

df.shape()
df.info()
df.describe()
df.rows()
df.column()
df.index()
df.dtypes()
df.sample()

# %% [markdown]
# # Data Table Display
#
# Colab includes an extension that renders pandas dataframes into interactive displays that can be filtered, sorted, and explored dynamically.
#
# Data table display for Pandas dataframes can be enabled by running:
# ```python
# from google.colab import data_table
# data_table.enable_dataframe_formatter()
# ```
# and disabled by running
# ```python
# from google.colab import data_table
# data_table.disable_dataframe_formatter()
# ```

# %% [markdown]
# ## Exploring Data Tables
#
# Here is an example of a data table display:

# %%
from google.colab import data_table
import vega_datasets

data_table.enable_dataframe_formatter()

vega_datasets.data.airports()

# %% [markdown]
# A few interesting features of the data table display:
#
# - Clicking the <button>Filter</button> button in the upper right allows you to search for terms or values in any particular column.
# - Clicking on any column title lets you sort the results according to that column's value.
# - The table displays only a subset of the data at a time. You can navigate through pages of data using the controls on the lower right.

# %% [markdown]
# ## Disabling Data Table Display
#
# To restore the native pandas dataframe display, use the following:

# %%
from google.colab import data_table

data_table.disable_dataframe_formatter()

vega_datasets.data.airports()

# %% [markdown]
# ## Customizing the Data Table Display

# %% [markdown]
# If you would like to create data tables directly, you can do that with the Python API, which allows additional customizations via keyword arguments:

# %%
from google.colab import data_table

data_table.DataTable(
    vega_datasets.data.airports(), include_index=False, num_rows_per_page=10
)
